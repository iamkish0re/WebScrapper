# %%
import pandas as pd

# %%
df = pd.read_csv(r'./Dataset/job_scrap.csv')

# %%
pd.set_option('display.max_colwidth', None)
df.drop(columns=['Unnamed: 0'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#                location                         title  \
# 0  Bengaluru, Karnataka                Data Scientist
# 1  Bengaluru, Karnataka         Senior Data Scientist
# 2  Bengaluru, Karnataka  Data Scientist - SQL Queries
# 3   Chennai, Tamil Nadu    newClinical Data Scientist
# 4  Hyderabad, Telangana   newAssociate Data Scientist
#
#                           company                         salary  \
# 0          Applied Materials Inc.  ₹5,26,846 - ₹17,85,107 a year
# 1  CORESTRAT LABS PRIVATE LIMITED              ₹30,00,000 a year
# 2                       Talent500                            NaN
# 3                          Pfizer                            NaN
# 4                        Gramener                            NaN
#
#                                                                                                                                                                  summary  \
# 0     \nAcquire, cleanse, organize and mine massive volumes of data (sensor/system log) using custom scripts Learn, understand and apply customer data in statistical…\n
# 1     \nCollaborate to enhance data infrastructure and build a seamless research platform.\nDeliver real impact to the product through rigorous data-driven solutions.\n
# 2   \nYou execute deep & complex quantitative analyses that translate data into actionable insights.\nAs a Lead Business Analyst, you are expected to have a top-down…\n
# 3  \nEnsure operational excellence in collaboration with partners for application of standards, data acquisition, proactive data review and data integrity monitoring…\n
# 4      \nFeel the thrill of using data to tell stories.\nLearn the ropes of converting Data Problems to Data Answers using AI/ML.\nAny graduate or final year student.\n
#
#    rating
# 0     3.9
# 1     NaN
# 2     NaN
# 3     4.2
# 4     4.3

# %%
display(df.describe(include='all'))
len(df)
# Out:
#                     location            title company     salary  \
# count                  12501            12501   12501       2285
# unique                   311             2375    1945        494
# top     Bengaluru, Karnataka  DevOps Engineer     IBM  Full-time
# freq                    3173              521    1623        813
# mean                     NaN              NaN     NaN        NaN
# std                      NaN              NaN     NaN        NaN
# min                      NaN              NaN     NaN        NaN
# 25%                      NaN              NaN     NaN        NaN
# 50%                      NaN              NaN     NaN        NaN
# 75%                      NaN              NaN     NaN        NaN
# max                      NaN              NaN     NaN        NaN
#
#                                                                                                                                                                     summary  \
# count                                                                                                                                                                 12501
# unique                                                                                                                                                                 3745
# top     \nSoftware Developers at IBM are the backbone of our strategic initiatives to design, code, test, and provide industry-leading solutions that make the world run…\n
# freq                                                                                                                                                                    559
# mean                                                                                                                                                                    NaN
# std                                                                                                                                                                     NaN
# min                                                                                                                                                                     NaN
# 25%                                                                                                                                                                     NaN
# 50%                                                                                                                                                                     NaN
# 75%                                                                                                                                                                     NaN
# max                                                                                                                                                                     NaN
#
#              rating
# count   7044.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean       3.886783
# std        0.334792
# min        1.000000
# 25%        3.700000
# 50%        3.900000
# 75%        4.000000
# max        5.000000
# 12501

# %%
df.isna().sum()
# Out:
# location        0
# title           0
# company         0
# salary      10216
# summary         0
# rating       5457
# dtype: int64

# %%
10216/12501
# Out:
# 0.8172146228301735

# %%
df = df[df.duplicated()]

# %%
display(df.describe(include='all'))
len(df)
# Out:
#                     location            title company     salary  \
# count                   8121             8121    8121       1018
# unique                    99              565     325         72
# top     Bengaluru, Karnataka  DevOps Engineer     IBM  Full-time
# freq                    2010              357    1260        433
# mean                     NaN              NaN     NaN        NaN
# std                      NaN              NaN     NaN        NaN
# min                      NaN              NaN     NaN        NaN
# 25%                      NaN              NaN     NaN        NaN
# 50%                      NaN              NaN     NaN        NaN
# 75%                      NaN              NaN     NaN        NaN
# max                      NaN              NaN     NaN        NaN
#
#                                                                                                                                                                     summary  \
# count                                                                                                                                                                  8121
# unique                                                                                                                                                                  711
# top     \nSoftware Developers at IBM are the backbone of our strategic initiatives to design, code, test, and provide industry-leading solutions that make the world run…\n
# freq                                                                                                                                                                    478
# mean                                                                                                                                                                    NaN
# std                                                                                                                                                                     NaN
# min                                                                                                                                                                     NaN
# 25%                                                                                                                                                                     NaN
# 50%                                                                                                                                                                     NaN
# 75%                                                                                                                                                                     NaN
# max                                                                                                                                                                     NaN
#
#              rating
# count   4683.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean       3.909161
# std        0.323663
# min        2.300000
# 25%        3.700000
# 50%        3.900000
# 75%        4.000000
# max        5.000000
# 8121

# %%
print('Unique Locations  \t:', len(df.location.unique()))
print('Unique Title  \t\t:', len(df.title.unique()))
print('Unique Company  \t:', len(df.company.unique()))
print('Unique Salary \t\t:', len(df.salary.unique()))
print('Unique Rating \t\t:', len(df.rating.unique()))
# Unique Locations  	: 385
# Unique Title  		: 3409
# Unique Company  	: 2426
# Unique Salary 		: 605
# Unique Rating 		: 31
# Out:
# Unique Locations  	: 99
# Unique Title  		: 565
# Unique Company  	: 325
# Unique Salary 		: 73
# Unique Rating 		: 22
