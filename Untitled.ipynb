# %%
import pandas as pd

# %%
df = pd.read_csv(r'./Dataset/job_raw.csv')

# %%
pd.set_option('display.max_colwidth', None)
df.drop(columns=['Unnamed: 0'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#                          location  \
# 0            Bengaluru, Karnataka
# 1            Bengaluru, Karnataka
# 2            Noida, Uttar Pradesh
# 3            Bengaluru, Karnataka
# 4  Chennai, Tamil Nadu+1 location
#
#                                              title  \
# 0                                   Data Scientist
# 1                            Senior Data Scientist
# 2  Tech Mahindra hiring for Data Scientist - Noida
# 3                                newData Scientist
# 4                      newAssociate Data Scientist
#
#                           company                         salary  \
# 0          Applied Materials Inc.  ₹5,26,846 - ₹17,85,107 a year
# 1  CORESTRAT LABS PRIVATE LIMITED              ₹30,00,000 a year
# 2                   Tech Mahindra  ₹4,00,000 - ₹16,00,000 a year
# 3                          Happay  ₹8,00,000 - ₹12,00,000 a year
# 4                           Shell                            NaN
#
# ...

# %%
display(df.describe(include='all'))
len(df)
# Out:
#                     location            title company     salary  \
# count                   5418             5418    5418       1316
# unique                   385             3409    2426        604
# top     Bengaluru, Karnataka  DevOps Engineer     IBM  Full-time
# freq                    1426              165     362        248
# mean                     NaN              NaN     NaN        NaN
# std                      NaN              NaN     NaN        NaN
# min                      NaN              NaN     NaN        NaN
# 25%                      NaN              NaN     NaN        NaN
# 50%                      NaN              NaN     NaN        NaN
# 75%                      NaN              NaN     NaN        NaN
# max                      NaN              NaN     NaN        NaN
#
#                                                                                                                                                                         summary  \
# ...

# %%
df.isna().sum()
# Out:
# location       0
# title          0
# company        0
# salary      4102
# summary        0
# rating      2392
# dtype: int64

# %%
4102/5418
# Out:
# 0.7571059431524548
